# %% [markdown]
# <a href="https://colab.research.google.com/github/sukaran/nlp-nltk-exercises/blob/master/assign1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.book import *
print(text5.collocation_list(num=20))
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7ce3dc55ee3b> in <module>()
#       1 import nltk
#       2 from nltk.book import *
# ----> 3 print(text5.collocation_list(num=20))
#
# AttributeError: 'Text' object has no attribute 'collocation_list'

# %%
my_sent=['this','is','a','book']
string=' '.join(my_sent)
split_string=string.split(' ')
print(split_string)
# Out:
# ['this', 'is', 'a', 'book']

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# True

# %%
print(text9.index('sunset'))
# Out:
# 629

# %%
sent_list=sent1+sent2+sent3+sent4+sent5+sent6+sent7+sent8
s=set()
for i in sent_list:
    s.add(i.lower())

print(len(s))
# Out:
# 72

# %%
(sorted(set([w.lower() for w in text1]))) 
#(sorted([w.lower() for w in set(text1)]))

#print(text2[-2:])
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
import nltk
from nltk.corpus import brown
from nltk.book import *

def percent(word,text):
    count=list([[word.lower() for word in tex.split().count(word)] for tex in text])
    cnt = count[0]
    return cnt/len(text)*100

print(percent('ARTHUR',text6))

#[[word.lower() for word in text.split()] for text in data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-5e3380734e94> in <module>()
#       8     return cnt/len(text)*100
#       9
# ---> 10 print(percent('ARTHUR',text6))
#      11
#      12 #[[word.lower() for word in text.split()] for text in data]
#
# <ipython-input-75-5e3380734e94> in percent(word, text)
#       4
#       5 def percent(word,text):
# ----> 6     count=list([[word.lower() for word in tex.split().count(word)] for tex in text])
#       7     cnt = count[0]
#       8     return cnt/len(text)*100
#
# <ipython-input-75-5e3380734e94> in <listcomp>(.0)
#       4
#       5 def percent(word,text):
# ----> 6     count=list([[word.lower() for word in tex.split().count(word)] for tex in text])
#       7     cnt = count[0]
#       8     return cnt/len(text)*100
#
# TypeError: 'int' object is not iterable

# %%
# Out:
# Member Meronyms:
#
# []
#
#  Part Meronyms:
#
# [Synset('burl.n.02'), Synset('crown.n.07'), Synset('limb.n.02'), Synset('stump.n.01'), Synset('trunk.n.01')]
#
#  Substance Meronyms:
#
# [Synset('heartwood.n.01'), Synset('sapwood.n.01')]
#
#  Member Holonyms:
#
# [Synset('forest.n.01')]
#
#  Part Holonyms:
#
# []
#
#  Substance Holonyms:
#
# []
# ----------
#
# Member Meronyms:
#
# []
#
#  Part Meronyms:
#
# []
#
#  Substance Meronyms:
#
# []
#
#  Member Holonyms:
#
# []
#
#  Part Holonyms:
#
# []
#
#  Substance Holonyms:
#
# [Synset('mead.n.03'), Synset('oenomel.n.01')]
# ----------
#
# Member Meronyms:
#
# []
#
#  Part Meronyms:
#
# []
#
#  Substance Meronyms:
#
# [Synset('lignin.n.01')]
#
#  Member Holonyms:
#
# []
#
#  Part Holonyms:
#
# []
#
#  Substance Holonyms:
#
# [Synset('beam.n.02'), Synset('chopping_block.n.01'), Synset('lumber.n.01'), Synset('spindle.n.02')]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
all_synsets = wn.all_synsets()
synsets_per_word = [synst for synst in all_synsets]
synsets_per_word
# Out:
# [Synset('able.a.01'),
#  Synset('unable.a.01'),
#  Synset('abaxial.a.01'),
#  Synset('adaxial.a.01'),
#  Synset('acroscopic.a.01'),
#  Synset('basiscopic.a.01'),
#  Synset('abducent.a.01'),
#  Synset('adducent.a.01'),
#  Synset('nascent.a.01'),
#  Synset('emergent.s.02'),
#  Synset('dissilient.s.01'),
#  Synset('parturient.s.02'),
#  Synset('dying.a.01'),
#  Synset('moribund.s.02'),
#  Synset('last.s.05'),
#  Synset('abridged.a.01'),
#  Synset('cut.s.03'),
#  Synset('half-length.s.02'),
#  Synset('potted.s.03'),
#  Synset('unabridged.a.01'),
#  Synset('full-length.s.02'),
#  Synset('absolute.a.01'),
#  Synset('direct.s.10'),
#  Synset('implicit.s.02'),
#  Synset('infinite.s.04'),
#  Synset('living.s.03'),
#  Synset('relative.a.01'),
#  Synset('relational.s.01'),
#  Synset('absorbent.a.01'),
#  Synset('absorbefacient.s.01'),
#  Synset('assimilating.s.01'),
#  Synset('hygroscopic.s.01'),
#  Synset('receptive.s.04'),
#  Synset('shock-absorbent.s.01'),
#  Synset('spongy.s.02'),
# ...

# %%
def vocab_size(text):
    s=set()
    for i in text:
        s.add(i.lower())
    return len(s)
v_size=vocab_size(text6)
v_size
# Out:
# 1855

# %%
sent=['she','sells','sea','shells','by','the','sea','shore']
sh_list=sorted(w for w in sent if w.startswith('sh'))
sh_list
# Out:
# ['she', 'shells', 'shore']

# %%
longer=sorted(w for w in sent if len(w)>4)
sh_list
# Out:
# ['she', 'shells', 'shore']

# %%
avg_word_length=sum([len(w) for w in text1])/len(text1)
avg_word_length
# Out:
# 3.830411128023649

# %%
ize_list=sorted(w for w in set(text6) if w.endswith('ize'))
ize_list
# Out:
# []

# %%
titlecase=sorted(item for item in set(text6) if item.istitle())
titlecase
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
z_list=sorted(w for w in set(text6) if 'z' in w)
z_list
# Out:
# ['Fetchez', 'amazes', 'frozen', 'zhiv', 'zone', 'zoo', 'zoop', 'zoosh']

# %%
pt_list=sorted(w for w in set(text6) if 'pt' in w)
pt_list
# Out:
# ['Chapter',
#  'Thpppppt',
#  'Thppppt',
#  'Thpppt',
#  'Thppt',
#  'aptly',
#  'empty',
#  'excepting',
#  'ptoo',
#  'temptation',
#  'temptress']

# %%
for word in text6:
    if word.isupper():
        print(word)
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %%
fdist1 = FreqDist([w for w in text5 if len(w) == 4])
vocab1 = fdist1.keys()
print((vocab1))
# Out:
# dict_keys(['left', 'with', 'this', 'name', 'PART', 'well', 'NICK', 'U121', 'golf', 'clap', 'JOIN', 'that', 'nice', 'fuck', 'your', 'dont', 'even', 'know', 'what', 'chat', 'drew', 'cast', 'sexy', 'U115', 'girl', 'legs', 'hope', 'draw', 'head', 'good', 'take', 'have', 'docs', 'Slip', 'away', 'Fade', 'Days', 'feel', 'back', 'U129', 'fast', 'U116', 'bowl', 'bong', 'glad', 'hard', 'from', 'here', 'very', 'fire', 'itch', 'U133', 'ogan', 'male', 'show', 'will', 'talk', 'haha', 'opps', 'warm', 'guys', 'cams', 'play', 'sits', 'guyz', 'U126', 'gooo', 'sure', 'like', 'room', 'yeee', 'want', 'pics', 'look', 'U139', 'U138', 'make', 'late', 'lmao', 'ahah', 'does', 'yeah', 'U136', 'hell', 'U101', 'when', 'plan', 'gold', 'jeep', 'ring', 'isnt', 'doin', 'many', 'Just', 'fine', 'hiya', 'Deep', 'Show', 'love', 'Turn', 'Hand', 'just', 'hang', 'such', 'word', 'U141', 'hear', '!!!!', 'deaf', '....', 'hugs', 'baby', 'Only', 'read', 'VBox', 'hate', 'more', 'than', 'ELSE', 'serg', 'most', 'eyes', 'jerk', 'ki
# ...

# %%
(sorted(set([w.lower() for w in text1])))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
(sorted([w.lower() for w in set(text1)]))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
print(text2[-2:])
# Out:
# ['THE', 'END']

# %%
import nltk
from nltk.book import *
print(text5.collocation_list(num=20))

from nltk.text import Text
text458 = Text(eng_corpus.words())
text458.collocation_list()
['Hong Kong', 'United States', 'Getty Images', 'European Union', 'Northern Ireland', 'Boris Johnson', 'Prime Minister', 'Islamic State', 'Extinction Rebellion', 'Cape Dorset', 'extradition bill', 'Recep Tayyip', 'HONG KONG', 'Mike Pence', 'New York', 'Tayyip Erdogan', 'Democratic Forces', 'Vice President', 'Anthony Kwan', 'Kurdish fighters']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-7ce3dc55ee3b> in <module>()
#       1 import nltk
#       2 from nltk.book import *
# ----> 3 print(text5.collocation_list(num=20))
#
# AttributeError: 'Text' object has no attribute 'collocation_list'

# %%
my_sent=['this','is','a','book']
string=' '.join(my_sent)
split_string=string.split(' ')
print(split_string)
# Out:
# ['this', 'is', 'a', 'book']

# %%
print(text9.index('sunset'))
# Out:
# 629

# %%
def percent(word, text):
	num_occurances = float(text.count(word))
	num_total = float(len(text))
	return str(round(100 * (num_occurances / num_total),2)) + ' %'

print (percent("the", text1))
# Out:
# 5.26 %
# ERROR! Session/line number was not unique in database. History logging moved to new session 60
